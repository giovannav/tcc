039272785187, 0.42805275321006775, 0.5728057622909546, 0.46660855412483215, 0.4664924442768097, 0.4264366328716278, 0.512157142162323, 0.41534748673439026, 0.45190873742103577, 0.4166686534881592, 0.42663970589637756, 0.4271683096885681, 0.41145333647727966, 0.4265349507331848, 0.40750861167907715, 0.40610823035240173, 0.41254302859306335, 0.4395792782306671, 0.45441100001335144, 0.4810307025909424, 0.4377966523170471, 0.4071388244628906, 0.40444108843803406, 0.4417628049850464, 0.42517709732055664, 0.4240596890449524, 0.4013640880584717, 0.4096187353134155, 0.41853106021881104, 0.3960713744163513, 0.4119969606399536, 0.5189880132675171, 0.3401443064212799, 0.4019768238067627, 0.4407786428928375, 0.3816335201263428, 0.361728310585022, 0.34750211238861084, 0.3467058539390564, 0.4289434254169464, 0.4238628149032593, 0.35075265169143677, 0.3805651068687439] 

x = list(itertools.chain(range(0, len(Accuracy_list))))

plt.plot(x, Accuracy_list)
plt.plot(x, Val_Accuracy_list)
plt.show()

plt.plot(x, Loss_list)
plt.plot(x, Val_Loss_list)
plt.show()

# %%
# evaluating result from test images
import os
import numpy as np
from tensorflow.keras.preprocessing import image

# %%
with open("images/camas.jpg", "rb") as f:
    img = f.read()

# %%
from PIL import Image

# %%
#img = Image.open('2023-08-11_images/2023-08-11-161641.jpg')

# %%
import cv2

# %%
from keras.models import load_model
model = load_model('model_checkpoint-model-NN7CUSTOM2-epochs-100-imgshape-150-batchsize-12-2023-08-29_19-40-33.h5')

# %%
img = plt.imread('camas_tiles_test/camendoim6sCenL1/camendoim6sCenL1 (99)_bottom_right.jpg')
# print(img.shape)
# plt.imshow(img)
img  = cv2.resize(img, (150, 150), interpolation = cv2.INTER_AREA)
plt.imshow(img)
img = (np.expand_dims(img, 0))
predictions_single = model.predict(img)
classes = ['Frente+Umida', 'Fundo+Intermediaria', 'Meio+Seca', 'camendoim6sCenL1'] 
classes[predictions_single.argmax()]
# Out:
# 1/1 [==============================] - 2s 2s/step
# 'camendoim6sCenL1'

# %%
image_directory = 'camas_tiles_test/camendoim6sCenL1/'  # Change this to your image directory

# List to store results
results = []

# Iterate over images in the directory
for filename in os.listdir(image_directory):
    if filename.endswith('.jpg'):
        img_path = os.path.join(image_directory, filename)
        
        # Load and preprocess the image
        img = plt.imread(img_path)
        img = cv2.resize(img, (150, 150), interpolation=cv2.INTER_AREA)
        img = np.expand_dims(img, 0)
        
        # Make predictions using the model
        predictions_single = model.predict(img)
        
        # Get the predicted class index and name
        predicted_class_index = predictions_single.argmax()
        predicted_class_name = classes[predicted_class_index]
        
        # Append the result to the list
        results.append((filename, predicted_class_name))
        
        # Display the image and result
        # plt.imshow(img[0])
        # plt.title(predicted_class_name)
        # plt.show()

# Print the results
for filename, predicted_class_name in results:
    print(f"{filename}: {predicted_class_name}")
# Out:
# ...
# 1/1 [==============================] - 0s 108ms/step
# Meio+Seca (1)_bottom_left.jpg: Frente+Umida
# Meio+Seca (10)_middle_right.jpg: Meio+Seca
# Meio+Seca (10)_top_left.jpg: camendoim6sCenL1
# Meio+Seca (100)_middle_left.jpg: Fundo+Intermediaria
# Meio+Seca (100)_top_right.jpg: camendoim6sCenL1
# Meio+Seca (101)_middle_middle.jpg: Meio+Seca
# Meio+Seca (102)_middle_left.jpg: Meio+Seca
# Meio+Seca (102)_middle_middle.jpg: Frente+Umida
# Meio+Seca (103)_middle_middle.jpg: Meio+Seca
# Meio+Seca (103)_top_middle.jpg: Fundo+Intermediaria
# Meio+Seca (104)_bottom_left.jpg: Meio+Seca
# Meio+Seca (105)_bottom_right.jpg: Frente+Umida
# Meio+Seca (106)_middle_right.jpg: Meio+Seca
# Meio+Seca (106)_top_middle.jpg: Fundo+Intermediaria
# Meio+Seca (107)_bottom_right.jpg: Frente+Umida
# Meio+Seca (107)_middle_middle.jpg: Fundo+Intermediaria
# Meio+Seca (108)_bottom_right.jpg: camendoim6sCenL1
# Meio+Seca (110)_bottom_left.jpg: Meio+Seca
# Meio+Seca (110)_bottom_middle.jpg: Meio+Seca
# ...

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Load your trained model
model = load_model('results_h5/model-model-NN7CUSTOM2-epochs-100-imgshape-150-batchsize-12-2023-08-29_19-40-33-epochs-100-imgshape-150-batchsize-12-2023-08-29_20-36-47.h5')

# List of classes
classes = ['Frente+Umida', 'Fundo+Intermediaria', 'Meio+Seca', 'camendoim6sCenL1']

# Directory containing images
image_directory = 'camas_tiles_test/'  # Change this to your image directory

# Lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate over directories (classes)
for class_name in classes:
    class_directory = os.path.join(image_directory, class_name)
    
    for filename in os.listdir(class_directory):
        if filename.endswith('.jpg'):
            img_path = os.path.join(class_directory, filename)
            
            # Load and preprocess the image
            img = plt.imread(img_path)
            img = cv2.resize(img, (150, 150), interpolation=cv2.INTER_AREA)
            img = np.expand_dims(img, 0)
            
            # Make predictions using the model
            predictions_single = model.predict(img)
            
            # Get the predicted class index and name
            predicted_class_index = predictions_single.argmax()
            predicted_class_name = classes[predicted_class_index]
            
            # Append true and predicted labels
            true_labels.append(class_name)
            predicted_labels.append(predicted_class_name)

# Calculate confusion matrix
confusion = confusion_matrix(true_labels, predicted_labels, labels=classes)
print(confusion)
# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=confusion, display_labels=classes)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 54ms/step
# [[50  0  0 10]
#  [17 27 21 12]
#  [37  3 59 15]
#  [ 1  0  0 96]]

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Load your trained model
model = load_model('results_h5/model-model-NN7CUSTOM2-epochs-100-imgshape-150-batchsize-12-2023-08-29_19-40-33-epochs-100-imgshape-150-batchsize-12-2023-08-29_20-36-47.h5')

# List of classes
classes = ['Frente+Umida', 'Fundo+Intermediaria', 'Meio+Seca', 'camendoim6sCenL1']

# Directory containing images
image_directory = 'camas_tiles_test/'  # Change this to your image directory

# Lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate over directories (classes)
for class_name in classes:
    class_directory = os.path.join(image_directory, class_name)
    
    for filename in os.listdir(class_directory):
        if filename.endswith('.jpg'):
            img_path = os.path.join(class_directory, filename)
            
            # Load and preprocess the image
            img = plt.imread(img_path)
            img = cv2.resize(img, (150, 150), interpolation=cv2.INTER_AREA)
            img = img / 255.0  # Normalize the image
            img = np.expand_dims(img, 0)
            
            # Make predictions using the model
            predictions_single = model.predict(img)
            
            # Get the predicted class index and name
            predicted_class_index = predictions_single.argmax()
            predicted_class_name = classes[predicted_class_index]
            
            # Append true and predicted labels
            true_labels.append(class_name)
            predicted_labels.append(predicted_class_name)

# Calculate confusion matrix
confusion = confusion_matrix(true_labels, predicted_labels, labels=classes)
print(confusion)
# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=confusion, display_labels=classes)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 32ms/step
# [[55  4  0  1]
#  [ 3 66  8  0]
#  [ 2 20 92  0]
#  [ 0  0  0 97]]

# %%
# Out:
# 1/1 [==============================] - 0s 107ms/step

# %%
# Out:
# array([[0., 0., 0., 1.]], dtype=float32)

# %%
# Out:
# 'camendoim6sCenL1'

# %%
predictions_single.argmax()
# Out:
# 3

# %%
list = [9.9993157e-01, 2.26949357e-13, 6.8391557e-05, 2.1782054e-27]

# %%
list
# Out:
# [0.99993157, 2.26949357e-13, 6.8391557e-05, 2.1782054e-27]

# %%
max(list)
# Out:
# 0.99993157

# %%
max(predictions_single.tolist()[0])
# Out:
# 1.0

# %%
type(predictions_single)
# Out:
# numpy.ndarray

# %%
classes[predictions_single.argmax()]
# Out:
# 'Frente+Umida'

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Read the CSV file
data = pd.read_csv('results_txt/model-vgg19es16-outputnodes-256-epochs-100-imgshape-128-batchsize-8-2023-08-23_23-26-50.csv')

# Extract data
epochs = data['epoch']
train_accuracy = data['accuracy']
train_loss = data['loss']
val_accuracy = data['val_accuracy']
val_loss = data['val_loss']

# Plotting
plt.figure(figsize=(12, 6))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, train_accuracy, label='Train Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Read the CSV file
data = pd.read_csv('results_txt/model-NN6-3-layers-256-128-64-epochs-100-imgshape-128-batchsize-8-2023-08-24_06-17-01.csv')

# Extract data
epochs = data['epoch']
train_accuracy = data['accuracy']
train_loss = data['loss']
val_accuracy = data['val_accuracy']
val_loss = data['val_loss']

# Plotting
plt.figure(figsize=(12, 6))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, train_accuracy, label='Train Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
#model-NN7CUSTOM2-epochs-100-imgshape-150-batchsize-12-2023-08-29_19-40-33

# Read the CSV file
data = pd.read_csv('results_txt/model-NN7CUSTOM2-epochs-100-imgshape-150-batchsize-12-2023-08-29_19-40-33.csv')

# Extract data
epochs = data['epoch']
train_accuracy = data['accuracy']
train_loss = data['loss']
val_accuracy = data['val_accuracy']
val_loss = data['val_loss']

# Plotting
plt.figure(figsize=(12, 6))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, train_accuracy, label='Train Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.yticks(np.arange(0, 1.1, 0.5))  # Set y-axis interval
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yticks(np.arange(0, 1.1, 0.5))  # Set y-axis interval
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Read the CSV file
data = pd.read_csv('results_txt/model-NN7CUSTOM2-epochs-100-imgshape-150-batchsize-12-2023-08-29_20-37-44.csv')

# Extract data
epochs = data['epoch']
train_accuracy = data['accuracy']
train_loss = data['loss']
val_accuracy = data['val_accuracy']
val_loss = data['val_loss']

# Plotting
plt.figure(figsize=(12, 6))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, train_accuracy, label='Train Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
